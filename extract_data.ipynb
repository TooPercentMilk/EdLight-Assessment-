# %%
import pandas as pd
import numpy as np
import os
import cv2

# %%
def extract():
    imgs = []
    img_names = []

    path = os.getcwd()
    filename = path + '/Data/descriptions.csv'
    captions = pd.read_csv(filename)

    directory = path + '/Data/images/'

    img_filenames = os.listdir(directory)

    for f in img_filenames:
        if f.endswith('.jpg'):
            imgs.append(cv2.imread(directory + f))
            img_names.append(f)

    imgs = np.array(imgs)
    images = pd.DataFrame({'filename': img_names, 'image_data': imgs})

    return captions, images

captions, images = extract()
# Out:
# /var/folders/9p/n09d6qfj5d99hs5gvj02l5kr0000gn/T/ipykernel_1527/4193630527.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   imgs = np.array(imgs)

# %%
# captions.head(40)
images.head(20)
# Out:
#                                     filename  \
# 0   28e3ea93-978e-4e79-ad29-7ade158ff608.jpg
# 1   4b4a5ad8-2ecf-4d0a-81c3-5b4594d61ac6.jpg
# 2   6bdce679-989b-4b34-baae-78272ec0a354.jpg
# 3   93a69e30-6234-4556-8cfd-1ea167d9f009.jpg
# 4   2e77f2c3-718c-4607-b05c-1add8501daa9.jpg
# 5   9428c3e1-8450-4300-96d9-a6496745b55b.jpg
# 6   94268d86-4c82-4c52-be21-dfbb9038bc37.jpg
# 7   fd029acb-2964-4ce5-b2e0-8273793a6324.jpg
# 8   fa4f5ee7-4ba7-4377-b966-b6116b383994.jpg
# 9   309cf33f-5276-4e38-908d-44b1154d9d30.jpg
# 10  9916ded4-ff2e-4ec1-8133-687078468d8c.jpg
# 11  1ab9e9a0-f639-428b-93ff-60ca9c2202c2.jpg
# 12  eff477d8-17a4-478a-bb14-2f7c0cd05732.jpg
# 13  e3f71c5f-881c-4df9-af1d-399f54a2f271.jpg
# 14  42f7a70e-faaf-4edf-abec-53f6dd3e8cb7.jpg
# 15  d0d10daa-d46f-44ab-8251-0ce7ec4d7fa4.jpg
# 16  12c26788-4c20-4aa7-a811-f5259e59f585.jpg
# 17  c4a62915-a07a-4451-b9f2-41adfa0dc40e.jpg
# 18  42ee6b25-6fba-4f29-bd2b-efbc7eb2edac.jpg
# 19  951a722a-ab21-4358-842c-ae67a7ece976.jpg
#
#                                            image_data
# 0   [[[242, 225, 132], [242, 225, 132], [242, 225,...
# 1   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2   [[[144, 144, 144], [149, 149, 149], [149, 149,...
# 3   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4   [[[198, 209, 217], [198, 209, 217], [198, 209,...
# 5   [[[237, 237, 237], [243, 243, 243], [252, 252,...
# 6   [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 7   [[[170, 179, 188], [200, 209, 218], [193, 202,...
# 8   [[[144, 253, 255], [145, 254, 255], [145, 254,...
# 9   [[[134, 87, 233], [135, 88, 234], [135, 88, 23...
# 10  [[[254, 254, 254], [254, 254, 254], [254, 254,...
# 11  [[[215, 225, 235], [215, 225, 235], [215, 225,...
# 12  [[[242, 242, 242], [159, 159, 159], [32, 32, 3...
# 13  [[[254, 254, 254], [248, 248, 248], [255, 255,...
# 14  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 15  [[[143, 239, 239], [143, 239, 239], [143, 239,...
# 16  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 17  [[[217, 231, 230], [217, 231, 230], [218, 232,...
# 18  [[[255, 255, 255], [251, 251, 251], [255, 255,...
# 19  [[[211, 224, 226], [211, 224, 226], [211, 224,...
